# %% [raw]
# ---
# description: The core of NN
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#| echo: false
#| output: asis
show_doc(Dense)
# Out:
# ---
#
# ### Dense
#
# >      Dense (n_inputs, n_neurons)
#
# Initilize params
#
# Args:
#     n_inputs (int): The number of features.
#     n_neurons (int): The number of neurons to have for the layer.

# %%
#| echo: false
#| output: asis
show_doc(spiral_data)
# Out:
# ---
#
# ### spiral_data
#
# >      spiral_data (samples=100, classes=3)
